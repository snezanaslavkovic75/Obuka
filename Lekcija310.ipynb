# %% [markdown]
# # 3.10. Vizuelna prezentacija sveske

# %% [markdown]
# ### Zadatak
# Pomoću *Markdown* jezika otkucaj tekst kao na narednoj slici. Na željena mesta umetni slike naših velikana. Na označena mesta umetni potrebne linkove.

# %% [markdown]
# # Sveto naucno trojstvo

# %% [markdown]
# ## Nikola Tesla

# %% [markdown]
# **Nikola Tesla** je najpoznatiji po svom doprinosu u projektovanju modernig sistema napajanja *naizmenicnom strujom*.

# %% [markdown]
# ![Slika01](https://i.imgur.com/uV86f0h.png)

# %% [markdown]
# ![Slika02](https://i.imgur.com/CO8lsY0.png)

# %% [markdown]
# Njegovi najznacajniji pronalasci su:
# - polifazni sistem
# - obrtno magnetno polje
# - asihroni motor
# - sinhroni motor
# - Teslin transformator

# %% [markdown]
# Njegovi najznacajniji pronalasci su:
# 1. polifazni sistem
# 1. obrtno magnetno polje
# 1. asihroni motor
# 1. sinhroni motor
# 1. Teslin transformator

# %% [markdown]
# ![Nikola-Tesla.jpg](attachment:Nikola-Tesla.jpg)

# %%
[Muzej Nikola Tesla](https://nikolateslamuseum.org/)
# Out:
#   File "/tmp/ipykernel_80/3986977472.py", line 1
#     [Muzej Nikola Tesla](https://nikolateslamuseum.org/)
#                 ^
# SyntaxError: invalid syntax

# %%
![Muzeј](https://nikolateslamuseum.org/)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://nikolateslamuseum.org/'
# /bin/bash: -c: line 0: `[Muzeј](https://nikolateslamuseum.org/)'
